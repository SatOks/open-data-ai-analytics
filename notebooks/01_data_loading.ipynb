# %% [markdown]
# # Завантаження даних Life Expectancy (WHO)
#
# Цей ноутбук демонструє завантаження та первинний огляд даних про очікувану тривалість життя.

# %%
import sys
sys.path.append('../src')

import pandas as pd
from data_load import load_data, get_data_info

# %% [markdown]
# ## Завантаження даних
#
# Завантажуємо датасет з файлу CSV.

# %%
# Завантаження даних
df = load_data()
df.head()

# %% [markdown]
# ## Базова інформація про датасет

# %%
# Отримання інформації про дані
info = get_data_info(df)

print(f"Розмір датасету: {info['shape']}")
print(f"\nСтовпці ({len(info['columns'])}):\n{info['columns']}")

# %%
# Типи даних
df.info()
